# %% [markdown]
# # DATA SET: Kids and teens screen time before and after COVID for more than 4 hours

# %%
print ('In this data set, the data |represents the amount of screen time for children before and during COVID for more than four hours as of June 2020.')
# Out:
# In this data set, the data |represents the amount of screen time for children before and during COVID for more than four hours as of June 2020.

# %% [markdown]
# [data set](https://drive.google.com/file/d/1oFvSX2W8g7tVoBGqaShDYbY3Uf0acjjl/view?usp=sharing).

# %%
print ('The question I want to ask of this data set is: How much has screen time gone up for kids and children during the pandemic?')
# Out:
# The question I want to ask of this data set is: How much has screen time gone up for kids and children during the pandemic?

# %%
print ('Once I crunch the numbers, I plan to show that screen time has increased dramatically for kids and teens since the start of COVID.')
# Out:
# Once I crunch the numbers, I plan to show that screen time has increased dramatically for kids and teens since the start of COVID.

# %%
import pandas as pd
df = pd.read_csv ('Kids and teens screentime before and after COVID for more than 4 hours.csv')

# %%
df.head()
# Out:
#                         Statistic as Excel data file Unnamed: 1  Unnamed: 2  \
# 0  Children and teens from the United States who ...        NaN         NaN
# 1                                        Access data        NaN         NaN
# 2                                                NaN        NaN         NaN
# 3                                                NaN        NaN         NaN
# 4                                             Source        NaN         NaN
#
#     Unnamed: 3
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4  Description

# %%
df.tail()
# Out:
#    Statistic as Excel data file     Unnamed: 1  Unnamed: 2 Unnamed: 3
# 17                          NaN            NaN         NaN        NaN
# 18                 Published by      eMarketer         NaN        NaN
# 19             Publication date         Nov-20         NaN        NaN
# 20              Original source  emarketer.com         NaN        NaN
# 21                           ID        1189204         NaN        NaN

# %%
df.sample()
# Out:
#   Statistic as Excel data file Unnamed: 1  Unnamed: 2 Unnamed: 3
# 1                  Access data        NaN         NaN        NaN

# %% [markdown]
# # DATA SET: Iphone and Yoga Usage

# %%
print('This dataset contains daily minutes of screen time, of a persons Iphone between April 17th and May 14th. On April 29th, the yoga experiment began. This data set is being used to see whether or not physical activity affects screen time.')
# Out:
# This dataset contains daily minutes of screen time, of a persons Iphone between April 17th and May 14th. On April 29th, the yoga experiment began. This data set is being used to see whether or not physical activity affects screen time.

# %% [markdown]
# [data set](https://data.world/taylynners04/screen-time-data).

# %%
print ('The question I want to ask of this data set is: Does physical activity affect screen time positvely or negatively?')
# Out:
# The question I want to ask of this data set is: Does physical activity affect screen time positvely or negatively?

# %%
print ('Once I crunch the numbers, I plan to present whether or not physical activity, such as yoga, has any affect on our screen time')
# Out:
# Once I crunch the numbers, I plan to present whether or not physical activity, such as yoga, has any affect on our screen time

# %%
import pandas as pd
df = pd.read_csv ('Iphone and yoga data.csv')

# %%
df.head(10)
# Out:
#         Date   Week Day  Total Screen Time   Social Networking  \
# 0  4/17/2019  Wednesday                 187                 89
# 1  4/18/2019   Thursday                 123                 78
# 2  4/19/2019     Friday                 112                 52
# 3  4/20/2019   Saturday                 101                 69
# 4  4/21/2019     Sunday                  56                 35
# 5  4/22/2019     Monday                 189                 68
# 6  4/23/2019    Tuesday                 158                 56
# 7  4/24/2019  Wednesday                 135                 98
# 8  4/25/2019   Thursday                  52                 25
# 9  4/26/2019     Friday                 198                 76
#
#    Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                     17     41            22                   0
# 1                     17      8             9                   0
# 2                     40      8             4                   0
# ...

# %%
df.tail(10)
# Out:
#          Date   Week Day  Total Screen Time   Social Networking  \
# 18   5/5/2019     Sunday                 133                109
# 19   5/6/2019     Monday                 144                 81
# 20   5/7/2019    Tuesday                 110                 70
# 21   5/8/2019  Wednesday                 122                 53
# 22   5/9/2019   Thursday                  96                 42
# 23  5/10/2019     Friday                 161                 93
# 24  5/11/2019   Saturday                  58                 49
# 25  5/12/2019     Sunday                  52                 28
# 26  5/13/2019     Monday                  61                 37
# 27  5/14/2019    Tuesday                  88                 41
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 18                      5      1             3                   0
# 19                      4      5             3                   0
# ...

# %%
df.sample()
# Out:
#         Date   Week Day  Total Screen Time   Social Networking  \
# 7  4/24/2019  Wednesday                 135                 98
#
#    Reading and Reference  Other  Productivity  Health and Fitness  \
# 7                      3     33            16                   0
#
#    Entertainment  Creativity  Yoga
# 7              0           0     0

# %% [markdown]
# # DATA SET: Typical smart phone usage

# %%
print('This dataset contains number of times participants checked their smart phone each day for 13 days')
# Out:
# This dataset contains number of times participants checked their smart phone each day for 13 days

# %% [markdown]
# [data set] (http://www.research.lancs.ac.uk/portal/en/datasets/typical-smartphone-usage-dataset(24cc8151-a0fc-4753-8fd9-efb0313a8651.html)

# %%
print ('The question I want to ask of this data set is: How much time are we on our phones per day?')
# Out:
# The question I want to ask of this data set is: How much time are we on our phones per day?

# %%
print ('Once I crunch the numbers, I plan to present the numbers of how much humans are typically on their phones per day')
# Out:
# Once I crunch the numbers, I plan to present the numbers of how much humans are typically on their phones per day

# %%
import pandas as pd
df = pd.read_csv ('typical smartphone usage.csv')

# %%
df.head(10)
# Out:
#                          Participant ID  \
# 0  a78403c4-efed-4327-9c82-a7adf79be146
# 1  ff47687c-fb5c-4e0e-9bec-86b4cb2f2494
# 2  0d7daff2-fa66-4195-aab0-634e58a51e9c
# 3  6a991364-08cb-43a0-b381-31fe42161e4c
# 4  b1233bc3-bfd3-4791-a48a-f3aa2ab8f475
# 5  2b7f3ffd-f0a6-4f6f-9a1c-f134d1c7cf86
# 6  9c8537a6-99f6-450c-a108-0ed2a98ac436
# 7  05489ce0-a21a-4444-9cfa-bf7ffa9e7fb9
# 8  b8d344e5-951c-4ac0-8455-44fecc0408b0
# 9  5ce5e5b1-9f83-46f0-beb4-6d0d8547b913
#
#    Score on mobile phone problematic use scale (MPPUS)  Age  \
# 0                                                120     19
# 1                                                 77     19
# 2                                                 80     33
# 3                                                100     21
# 4                                                 77     33
# 5                                                147     20
# 6                                                100     19
# ...

# %%
df.tail(10)
# Out:
#                           Participant ID  \
# 17  89573969-c537-47da-b938-ba88f230f2d6
# 18  3a09e504-a096-4950-87f8-52ace27a559e
# 19  734ffeea-9f27-4f31-bd13-ddcf4bcd7bb0
# 20  75341f67-d7fb-468a-bca6-f5c1a0f2a4b2
# 21  f47d8ac0-55e7-4f37-bd0c-f86a80f915a3
# 22  50a2c0c6-14e2-4808-83f5-d22af17deabb
# 23  669fe3f9-bb2e-46ce-b01e-6f320aeba642
# 24  b9e35756-73ce-4a61-a474-fa82485b85c9
# 25  03621474-8d7c-48be-8b9e-cbf1582a81b3
# 26  1ab4e9a3-858c-44d6-a163-734fc5040f85
#
#     Score on mobile phone problematic use scale (MPPUS)  Age  \
# 17                                                132     18
# 18                                                 61     27
# 19                                                141     21
# 20                                                 75     19
# 21                                                162     20
# 22                                                 55     25
# 23                                                123     20
# ...

# %%
df.sample()
# Out:
#                           Participant ID  \
# 23  669fe3f9-bb2e-46ce-b01e-6f320aeba642
#
#     Score on mobile phone problematic use scale (MPPUS)  Age  \
# 23                                                123     20
#
#     Gender (1 = female 2 = male)  Day1TotalChecks  Day2TotalChecks  \
# 23                             2               28               21
#
#     Day3TotalChecks  Day4TotalChecks  Day5TotalChecks  Day6TotalChecks  ...  \
# 23               55               62               29                6  ...
#
#     Day10HoursUse  Day11HoursUse  Day12HoursUse  Day13HoursUse  \
# 23      10.711444       6.160314       8.638208      16.485906
#
#     totalhoursweek1  totalhoursweek2  totalchecksweek1  totalchecksweek2  \
# 23        56.312697            80.99               201               149
#
#      total_use  total_checks
# 23  137.302697           350
#
# [1 rows x 36 columns]
